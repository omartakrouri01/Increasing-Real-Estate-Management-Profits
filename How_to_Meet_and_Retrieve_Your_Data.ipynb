# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # How to Meet and Retrieve Your Data

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# Here are some hints about how to write your query:
# * Start by joining no more than two tables.  After you have made sure the query works as written and that the output makes sense, add other tables one at a time, checking the new query and its results each time.
# * Your final output should have 244 rows.  Given the limited output, the easiest way to extract the results will be to copy and paste the output from your query into Excel, although you could also extract as a .csv file and open that with Excel.  If you choose the .csv option, you might find it necessary to write your query on multiple lines when you declare it as a variable.  To do this, type a space (if you forget the space the lines will run together) and a "\" at the end of each line of your query:
#
# ```
# my_data= %sql SELECT DISTINCT user_guid, state, membership_type \
# FROM users \
# WHERE country="US" AND state IS NOT NULL and membership_type IS NOT NULL \
# ORDER BY state ASC, membership_type ASC ;
#
# my_data.csv('my_data.csv')
# ```
#
# * We recommend that you calculate the occupancy rates of the example short-term rental properties within MySQL, rather than within Excel (it will be much faster!)  To do this, only examine rental dates during 2015, and remember that there are 365 days in the year.  The final output of your calculation should be the percentage of days in 2015 that the property was occupied.  You may want to consider using a subquery for this calculation.
# * Make sure that you extract information from short-term rentals <u>**_that have the same location and property type_**</u> as the 244 Watershed properties.
# * If you run into trouble, use your workbooks and Teradata notes from “Managing Big Data with MySQL” to remind you how to implement different parts of your query.
#
# <img src="https://duke.box.com/shared/static/svbdzasxe7nncnszps6ewnkr8og4798c.jpg" width="300" alt="SQL Master"/>

# %% [markdown]
# ## Good luck and have fun!

# %% [markdown]
# To get started, connect to the capstone database and set the database as your default database using the following commands:
#
# ```python
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/capstone
# %sql USE capstone
# ```

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/capstone 
# %sql USE capstone
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 0 rows affected.
# []

# %% [markdown]
# ### Queries
#
# You can add as many "cells" as you need in order to explore the database and extract the appropriate data.  For a reminder about what "cells" are, how to add them, or how to use Jupyter in general, please refer to the "How to Use Jupyter Notebooks" video at: https://www.coursera.org/learn/analytics-mysql/lecture/oxkUg/how-to-use-jupyter-notebooks.

# %%
# %%sql
# SHOW TABLES
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 6 rows affected.
# [('location',),
#  ('property_type',),
#  ('st_property_info',),
#  ('st_rental_dates',),
#  ('st_rental_prices',),
#  ('watershed_property_info',)]

# %%
# %%sql
# select *
# from property_type
# limit 100;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 16 rows affected.
# [('R1', 'apartment', '1', 'Y', 'Y'),
#  ('R10', 'house', '1', 'Y', 'N'),
#  ('R11', 'house', '1', 'N', 'Y'),
#  ('R12', 'house', '1', 'N', 'N'),
#  ('R13', 'house', '2', 'Y', 'Y'),
#  ('R14', 'house', '2', 'Y', 'N'),
#  ('R15', 'house', '2', 'N', 'Y'),
#  ('R16', 'house', '2', 'N', 'N'),
#  ('R2', 'apartment', '1', 'Y', 'N'),
#  ('R3', 'apartment', '1', 'N', 'Y'),
#  ('R4', 'apartment', '1', 'N', 'N'),
#  ('R5', 'apartment', '2', 'Y', 'Y'),
#  ('R6', 'apartment', '2', 'Y', 'N'),
#  ('R7', 'apartment', '2', 'N', 'Y'),
#  ('R8', 'apartment', '2', 'N', 'N'),
#  ('R9', 'house', '1', 'Y', 'Y')]

# %%
# %%sql
# SHOW COLUMNS FROM location;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 4 rows affected.
# [('location_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zipcode', 'int(5)', 'YES', '', None, '')]

# %%
# %%sql
# SHOW COLUMNS FROM property_type;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('property_type_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('apt_house', 'varchar(255)', 'YES', '', None, ''),
#  ('num_bedrooms', 'varchar(255)', 'YES', '', None, ''),
#  ('kitchen', 'varchar(255)', 'YES', '', None, ''),
#  ('shared', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SHOW COLUMNS FROM st_property_info;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 3 rows affected.
# [('st_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# SHOW columns FROM st_rental_dates
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 2 rows affected.
# [('rental_date', 'date', 'NO', 'PRI', None, ''),
#  ('st_property', 'varchar(255)', 'NO', 'PRI', None, '')]

# %%
# %%sql
# SHOW columns FROM st_rental_prices
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('location', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('property_type', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('percentile_10th_price', 'int(11)', 'YES', '', None, ''),
#  ('percentile_90th_price', 'int(11)', 'YES', '', None, ''),
#  ('sample_nightly_rent_price', 'int(11)', 'YES', '', None, '')]

# %%
# %%sql
# SHOW columns FROM watershed_property_info
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 4 rows affected.
# [('ws_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, ''),
#  ('current_monthly_rent', 'int(11)', 'NO', '', None, '')]

# %% [markdown]
# # What information is available for Watershed's 244 properties?

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.current_monthly_rent, w.property_type, p.apt_house, p.num_bedrooms, p.kitchen, p.shared,
# l.city, l.state, l.zipcode
# FROM watershed_property_info w, property_type p, location l
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id
#
#
# ;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 1060, 'R6', 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W10', 'L9533', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W100', 'L1944', 3300, 'R2', 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W101', 'L15257', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W102', 'L15257', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W103', 'L15257', 1600, 'R10', 'house', '1', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W104', 'L15257', 2800, 'R14', 'house', '2', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W105', 'L15260', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W106', 'L15260', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W107', 'L15260', 1800, 'R10', 'house', '1', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W108', 'L15260', 3200, 'R14', 'house', '2', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W109', 'L15264', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W11', 'L9533', 1000, 'R10', 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W110', 'L15264', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W111', 'L15264', 1200, 'R10', 'house', '1', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W112', 'L15264', 1600, 'R14', 'house', '2', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W113', 'L15278', 800, 'R2', 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W114', 'L15278', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W115', 'L15278', 900, 'R10', 'house', '1', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W116', 'L15278', 1100, 'R14', 'house', '2', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W117', 'L15280', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W118', 'L15280', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W119', 'L15280', 1500, 'R10', 'house', '1', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W12', 'L9533', 1300, 'R14', 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W120', 'L15280', 1600, 'R14', 'house', '2', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W121', 'L463', 600, 'R2', 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W122', 'L463', 800, 'R6', 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W123', 'L463', 700, 'R10', 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W124', 'L463', 1000, 'R14', 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W125', 'L464', 700, 'R2', 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W126', 'L464', 900, 'R6', 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W127', 'L464', 1000, 'R10', 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W128', 'L464', 1200, 'R14', 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W129', 'L2314', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W13', 'L9534', 920, 'R6', 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W130', 'L2314', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W131', 'L2314', 1100, 'R10', 'house', '1', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W132', 'L2314', 1200, 'R14', 'house', '2', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W133', 'L2318', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W134', 'L2318', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W135', 'L2318', 1200, 'R10', 'house', '1', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W136', 'L2318', 1900, 'R14', 'house', '2', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W137', 'L2323', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W138', 'L2323', 1500, 'R6', 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W139', 'L2323', 1300, 'R10', 'house', '1', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W14', 'L9534', 850, 'R10', 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W140', 'L2323', 1800, 'R14', 'house', '2', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W141', 'L2325', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W142', 'L2325', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W143', 'L2325', 1300, 'R10', 'house', '1', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W144', 'L2325', 1900, 'R14', 'house', '2', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W145', 'L2338', 900, 'R2', 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W146', 'L2338', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W147', 'L2338', 1400, 'R10', 'house', '1', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W148', 'L2338', 1700, 'R14', 'house', '2', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W149', 'L3244', 800, 'R2', 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W15', 'L9534', 900, 'R14', 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W150', 'L3244', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W151', 'L3244', 1400, 'R10', 'house', '1', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W152', 'L3244', 1900, 'R14', 'house', '2', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W153', 'L3256', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W154', 'L3256', 2400, 'R6', 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W155', 'L3256', 2100, 'R10', 'house', '1', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W156', 'L3256', 3200, 'R14', 'house', '2', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W157', 'L3261', 1300, 'R2', 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W158', 'L3261', 1700, 'R6', 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W159', 'L3261', 1400, 'R10', 'house', '1', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W16', 'L9534', 750, 'R2', 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W160', 'L3261', 1900, 'R14', 'house', '2', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W161', 'L3262', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W162', 'L3262', 2200, 'R6', 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W163', 'L3262', 1500, 'R10', 'house', '1', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W164', 'L3262', 2400, 'R14', 'house', '2', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W165', 'L3264', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W166', 'L3264', 1900, 'R6', 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W167', 'L3264', 1400, 'R10', 'house', '1', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W168', 'L3264', 2000, 'R14', 'house', '2', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W169', 'L10126', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W17', 'L4761', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W170', 'L10126', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W171', 'L10126', 1300, 'R10', 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W172', 'L10126', 1800, 'R14', 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W173', 'L10130', 700, 'R2', 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W174', 'L10130', 900, 'R6', 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W175', 'L10130', 1000, 'R10', 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W176', 'L10130', 1200, 'R14', 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W177', 'L10133', 700, 'R2', 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W178', 'L10133', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W179', 'L10133', 800, 'R10', 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W18', 'L4761', 2500, 'R10', 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W180', 'L10133', 900, 'R14', 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W181', 'L10136', 700, 'R2', 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W182', 'L10136', 1000, 'R6', 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W183', 'L10136', 900, 'R10', 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W184', 'L10136', 1200, 'R14', 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W185', 'L1882', 1100, 'R2', 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W186', 'L1882', 1400, 'R6', 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W187', 'L1882', 1300, 'R10', 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W188', 'L1882', 1900, 'R14', 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W189', 'L1883', 900, 'R2', 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W19', 'L4761', 2800, 'R14', 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W190', 'L1883', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W191', 'L1883', 1300, 'R10', 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W192', 'L1883', 1600, 'R14', 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W193', 'L1887', 1400, 'R2', 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W194', 'L1887', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W195', 'L1887', 1700, 'R10', 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W196', 'L1887', 2500, 'R14', 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W197', 'L1902', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W198', 'L1902', 2600, 'R6', 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W199', 'L1902', 2500, 'R10', 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W2', 'L9531', 1500, 'R10', 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W20', 'L4761', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W200', 'L1902', 3600, 'R14', 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W201', 'L1916', 1200, 'R2', 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W202', 'L1916', 1600, 'R6', 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W203', 'L1916', 1000, 'R10', 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W204', 'L1916', 1500, 'R14', 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W205', 'L12252', 750, 'R2', 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W206', 'L12252', 1040, 'R6', 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W207', 'L12252', 900, 'R10', 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W208', 'L12252', 1400, 'R14', 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W209', 'L12260', 825, 'R2', 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W21', 'L4765', 2700, 'R6', 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W210', 'L12260', 1300, 'R6', 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W211', 'L12260', 1000, 'R10', 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W212', 'L12260', 1480, 'R14', 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W213', 'L12264', 650, 'R2', 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W214', 'L12264', 920, 'R6', 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W215', 'L12264', 880, 'R10', 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W216', 'L12264', 1200, 'R14', 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W217', 'L16888', 1000, 'R2', 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W218', 'L16888', 1200, 'R6', 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W219', 'L16888', 1400, 'R10', 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W22', 'L4765', 2700, 'R10', 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W220', 'L16888', 1600, 'R14', 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W221', 'L16887', 1105, 'R2', 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W222', 'L16887', 1665, 'R6', 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W223', 'L16887', 1175, 'R10', 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W224', 'L16887', 1725, 'R14', 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W225', 'L16898', 709, 'R2', 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W226', 'L16898', 869, 'R6', 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W227', 'L16898', 925, 'R10', 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W228', 'L16898', 1350, 'R14', 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W229', 'L16890', 900, 'R2', 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W23', 'L4765', 3200, 'R14', 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W230', 'L16890', 1325, 'R6', 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W231', 'L16890', 975, 'R10', 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W232', 'L16890', 1550, 'R14', 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W233', 'L14416', 1165, 'R2', 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W234', 'L14416', 1625, 'R6', 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W235', 'L14416', 1400, 'R10', 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W236', 'L14416', 1995, 'R14', 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W237', 'L14418', 760, 'R2', 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W238', 'L14418', 965, 'R6', 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W239', 'L14418', 1185, 'R10', 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W24', 'L4765', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W240', 'L14418', 1340, 'R14', 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W241', 'L14419', 1150, 'R2', 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W242', 'L14419', 2000, 'R6', 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W243', 'L14419', 1600, 'R10', 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W244', 'L14419', 2150, 'R14', 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W25', 'L4770', 1600, 'R2', 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W26', 'L4770', 2100, 'R6', 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W27', 'L4770', 1200, 'R10', 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W28', 'L4770', 2100, 'R14', 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W29', 'L4794', 2500, 'R6', 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W3', 'L9531', 2000, 'R14', 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W30', 'L4794', 2500, 'R10', 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W31', 'L4794', 2750, 'R14', 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W32', 'L4794', 1800, 'R2', 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W33', 'L4804', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W34', 'L4804', 2000, 'R10', 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W35', 'L4804', 2950, 'R14', 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W36', 'L4804', 1700, 'R2', 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W37', 'L11419', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10002),
#  ('W38', 'L11419', 3200, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10002),
#  ('W39', 'L11421', 4500, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W4', 'L9531', 800, 'R2', 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W40', 'L11421', 4500, 'R10', 'house', '1', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W41', 'L11421', 5500, 'R14', 'house', '2', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W42', 'L11421', 3500, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W43', 'L11427', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10014),
#  ('W44', 'L11427', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10014),
#  ('W45', 'L11431', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W46', 'L11431', 3200, 'R10', 'house', '1', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W47', 'L11431', 3500, 'R14', 'house', '2', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W48', 'L11431', 3400, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W49', 'L11434', 4200, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W5', 'L9532', 1100, 'R6', 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W50', 'L11434', 3000, 'R10', 'house', '1', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W51', 'L11434', 3900, 'R14', 'house', '2', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W52', 'L11434', 3600, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W53', 'L11480', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W54', 'L11480', 2500, 'R10', 'house', '1', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W55', 'L11480', 3000, 'R14', 'house', '2', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W56', 'L11480', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W57', 'L11495', 3900, 'R6', 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W58', 'L11495', 2800, 'R10', 'house', '1', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W59', 'L11495', 3500, 'R14', 'house', '2', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W6', 'L9532', 900, 'R10', 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W60', 'L11495', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W61', 'L1734', 2695, 'R6', 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W62', 'L1734', 3000, 'R10', 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W63', 'L1734', 4000, 'R14', 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W64', 'L1734', 2295, 'R2', 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W65', 'L1735', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W66', 'L1735', 3300, 'R10', 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W67', 'L1735', 4500, 'R14', 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W68', 'L1735', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W69', 'L1736', 2700, 'R2', 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W7', 'L9532', 1100, 'R14', 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W70', 'L1736', 3000, 'R6', 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W71', 'L1736', 4500, 'R10', 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W72', 'L1736', 4900, 'R14', 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W73', 'L1737', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W74', 'L1737', 4500, 'R10', 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W75', 'L1737', 4200, 'R14', 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W76', 'L1737', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W77', 'L1738', 2500, 'R2', 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W78', 'L1738', 3300, 'R6', 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W79', 'L1738', 4500, 'R10', 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W8', 'L9532', 500, 'R2', 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W80', 'L1738', 4200, 'R14', 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W81', 'L1940', 3600, 'R6', 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W82', 'L1940', 4000, 'R10', 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W83', 'L1940', 5500, 'R14', 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W84', 'L1940', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W85', 'L1941', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W86', 'L1941', 4000, 'R10', 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W87', 'L1941', 5000, 'R14', 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W88', 'L1941', 3200, 'R2', 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W89', 'L1942', 3500, 'R6', 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W9', 'L9533', 965, 'R2', 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W90', 'L1942', 3200, 'R10', 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W91', 'L1942', 3500, 'R14', 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W92', 'L1942', 3000, 'R2', 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W93', 'L1943', 2600, 'R2', 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W94', 'L1943', 4000, 'R6', 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W95', 'L1943', 4000, 'R10', 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W96', 'L1943', 5100, 'R14', 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W97', 'L1944', 5600, 'R6', 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W98', 'L1944', 5000, 'R10', 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W99', 'L1944', 6000, 'R14', 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94129)]

# %% [markdown]
# # These properties are located in which distinct zip codes?

# %%
# %%sql
# SELECT DISTINCT l.zipcode
# FROM watershed_property_info w, location l
# WHERE w.location=l.location_id
# GROUP BY l.zipcode;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 62 rows affected.
# [(10002,),
#  (10004,),
#  (10014,),
#  (10019,),
#  (10023,),
#  (11101,),
#  (11211,),
#  (23060,),
#  (23113,),
#  (23220,),
#  (23234,),
#  (27514,),
#  (27516,),
#  (27517,),
#  (27707,),
#  (29438,),
#  (29470,),
#  (29487,),
#  (33122,),
#  (33137,),
#  (33146,),
#  (33149,),
#  (33178,),
#  (43201,),
#  (43212,),
#  (43222,),
#  (60607,),
#  (60611,),
#  (60616,),
#  (60642,),
#  (60654,),
#  (68046,),
#  (68106,),
#  (68110,),
#  (68114,),
#  (72712,),
#  (72719,),
#  (78702,),
#  (78705,),
#  (78723,),
#  (78744,),
#  (78746,),
#  (80204,),
#  (80209,),
#  (80218,),
#  (80220,),
#  (80249,),
#  (91910,),
#  (91950,),
#  (92102,),
#  (92118,),
#  (92154,),
#  (94025,),
#  (94103,),
#  (94110,),
#  (94112,),
#  (94118,),
#  (94129,),
#  (94301,),
#  (94303,),
#  (94305,),
#  (94306,)]

# %% [markdown]
# # Calculate occupancy rates for the short-term property example data
# Divide the number of days in 2015 that the property had been rented by the number of total days in 2015

# %%
# %%sql
# SELECT st_property, COUNT(rental_date) / 365 AS Occupancy
# FROM st_rental_dates
# WHERE YEAR(rental_date) = 2015
# GROUP BY st_property
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('ST1', Decimal('0.1616')),
#  ('ST10', Decimal('0.3479')),
#  ('ST100', Decimal('0.3973')),
#  ('ST1000', Decimal('0.9808')),
#  ('ST101', Decimal('0.3644')),
#  ('ST102', Decimal('0.4110')),
#  ('ST103', Decimal('0.4110')),
#  ('ST104', Decimal('0.5260')),
#  ('ST105', Decimal('0.4329')),
#  ('ST106', Decimal('0.6959'))]

# %% [markdown]
# # These occupancy rates correspond to which locations and property types?

# %%
# %%sql
# SELECT sd.st_property, COUNT(sd.rental_date)/365 AS Occupancy, si.location, si.property_type
# FROM st_property_info si JOIN st_rental_dates sd
#   ON si.st_property_id=sd.st_property
# WHERE EXTRACT(year FROM rental_date)=2015
# GROUP BY st_property
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('ST1', Decimal('0.1616'), 'L9531', 'R6'),
#  ('ST10', Decimal('0.3479'), 'L9533', 'R6'),
#  ('ST100', Decimal('0.3973'), 'L1944', 'R2'),
#  ('ST1000', Decimal('0.9808'), 'L5957', 'R1'),
#  ('ST101', Decimal('0.3644'), 'L15257', 'R2'),
#  ('ST102', Decimal('0.4110'), 'L15257', 'R6'),
#  ('ST103', Decimal('0.4110'), 'L15257', 'R10'),
#  ('ST104', Decimal('0.5260'), 'L15257', 'R14'),
#  ('ST105', Decimal('0.4329'), 'L15260', 'R2'),
#  ('ST106', Decimal('0.6959'), 'L15260', 'R6')]

# %% [markdown]
# # What are the sample nightly rent prices for these properties?

# %%
# %%sql
# SELECT i.st_property_id, p.sample_nightly_rent_price, i.location, i.property_type
# FROM st_property_info i JOIN st_rental_prices p
#   ON i.location=p.location
# GROUP BY st_property_id
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('ST1', 104, 'L9531', 'R6'),
#  ('ST10', 50, 'L9533', 'R6'),
#  ('ST100', 139, 'L1944', 'R2'),
#  ('ST101', 420, 'L15257', 'R2'),
#  ('ST102', 420, 'L15257', 'R6'),
#  ('ST103', 420, 'L15257', 'R10'),
#  ('ST104', 420, 'L15257', 'R14'),
#  ('ST105', 249, 'L15260', 'R2'),
#  ('ST106', 249, 'L15260', 'R6'),
#  ('ST107', 249, 'L15260', 'R10')]

# %% [markdown]
# # What is the nightly rent price for short-term rental examples corresponding to Watershed's properties of the same location and property type?

# %%
# %%sql
# SELECT wi.ws_property_id, wi.location, wi.property_type, sp.percentile_10th_price, sp.percentile_90th_price, sp.sample_nightly_rent_price
# FROM st_rental_prices sp JOIN watershed_property_info wi
# ON sp.location=wi.location AND sp.property_type=wi.property_type
# GROUP BY wi.ws_property_id
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('W1', 'L9531', 'R6', 114, 153, 148),
#  ('W10', 'L9533', 'R6', 111, 149, 133),
#  ('W100', 'L1944', 'R2', 108, 610, 372),
#  ('W101', 'L15257', 'R2', 178, 533, 302),
#  ('W102', 'L15257', 'R6', 221, 617, 429),
#  ('W103', 'L15257', 'R10', 202, 646, 380),
#  ('W104', 'L15257', 'R14', 197, 639, 374),
#  ('W105', 'L15260', 'R2', 114, 477, 386),
#  ('W106', 'L15260', 'R6', 80, 583, 212),
#  ('W107', 'L15260', 'R10', 239, 1431, 969)]

# %% [markdown]
# # Join the Watershed Property IDs with corresponding sample occupancy rates

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy
# FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365
#                                           AS Occupancy
#                                           FROM st_property_info si JOIN st_rental_dates sd
#                                             ON si.st_property_id=sd.st_property
#                                           WHERE year(rental_date)=2015
#                                           GROUP BY st_property) AS Sample
#   ON w.location=Sample.location AND w.property_type=Sample.property_type
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('W1', 'L9531', 'R6', Decimal('0.1616')),
#  ('W10', 'L9533', 'R6', Decimal('0.3479')),
#  ('W100', 'L1944', 'R2', Decimal('0.3973')),
#  ('W101', 'L15257', 'R2', Decimal('0.3644')),
#  ('W102', 'L15257', 'R6', Decimal('0.4110')),
#  ('W103', 'L15257', 'R10', Decimal('0.4110')),
#  ('W104', 'L15257', 'R14', Decimal('0.5260')),
#  ('W105', 'L15260', 'R2', Decimal('0.4329')),
#  ('W106', 'L15260', 'R6', Decimal('0.6959')),
#  ('W107', 'L15260', 'R10', Decimal('0.1096'))]

# %% [markdown]
# # Join the Watershed Property IDs with corresponding sample nightly rent prices

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen,
# p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price,
# sample_price.sample_nightly_rent_price
# FROM watershed_property_info w, location l, property_type p,
#      (SELECT wi.ws_property_id, wi.location, wi.property_type, sp.percentile_10th_price, sp.percentile_90th_price, sp.sample_nightly_rent_price
#       FROM st_rental_prices sp JOIN watershed_property_info wi
#        ON sp.location=wi.location AND sp.property_type=wi.property_type
#        GROUP BY wi.ws_property_id) AS sample_price
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id
# GROUP BY w.ws_property_id
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 10 rows affected.
# [('W1', 'L9531', 'R6', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148),
#  ('W10', 'L9533', 'R6', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133),
#  ('W100', 'L1944', 'R2', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372),
#  ('W101', 'L15257', 'R2', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302),
#  ('W102', 'L15257', 'R6', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429),
#  ('W103', 'L15257', 'R10', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380),
#  ('W104', 'L15257', 'R14', 'Austin', 'TX', 78702, 'house', '2', 'Y', 'N', 2800, 197, 639, 374),
#  ('W105', 'L15260', 'R2', 'Austin', 'TX', 78705, 'apartment', '1', 'Y', 'N', 1100, 114, 477, 386),
#  ('W106', 'L15260', 'R6', 'Austin', 'TX', 78705, 'apartment', '2', 'Y', 'N', 1900, 80, 583, 212),
#  ('W107', 'L15260', 'R10', 'Austin', 'TX', 78705, 'house', '1', 'Y', 'N', 1800, 239, 1431, 969)]

# %% [markdown]
# # Join the above two queries

# %%
# %%sql
# SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen,
# p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price,
# sample_price.sample_nightly_rent_price, sample_dates.Occupancy
# FROM watershed_property_info w, location l, property_type p,
#     (SELECT w.ws_property_id, w.location, w.property_type,
#      sp.percentile_10th_price, sp.percentile_90th_price,
#      sp.sample_nightly_rent_price
#      FROM watershed_property_info w JOIN st_rental_prices sp
#        ON w.location=sp.location AND w.property_type=sp.property_type
#      GROUP BY w.ws_property_id) AS sample_price,
#     (SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy
#      FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365
#                                                AS Occupancy
#                                                FROM st_property_info si JOIN st_rental_dates sd
#                                                  ON si.st_property_id=sd.st_property
#                                                WHERE EXTRACT(year FROM rental_date)=2015
#                                                GROUP BY st_property) AS Sample
#        ON w.location=Sample.location AND w.property_type=Sample.property_type
#      GROUP BY w.ws_property_id) AS sample_dates
# WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id AND
# w.ws_property_id=sample_dates.ws_property_id
# GROUP BY w.ws_property_id
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 'R6', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148, Decimal('0.1616')),
#  ('W10', 'L9533', 'R6', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133, Decimal('0.3479')),
#  ('W100', 'L1944', 'R2', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372, Decimal('0.3973')),
#  ('W101', 'L15257', 'R2', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302, Decimal('0.3644')),
#  ('W102', 'L15257', 'R6', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429, Decimal('0.4110')),
#  ('W103', 'L15257', 'R10', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380, Decimal('0.4110')),
#  ('W104', 'L15257', 'R14', 'Austin', 'TX', 78702, 'house', '2', 'Y', 'N', 2800, 197, 639, 374, Decimal('0.5260')),
#  ('W105', 'L15260', 'R2', 'Austin', 'TX', 78705, 'apartment', '1', 'Y', 'N', 1100, 114, 477, 386, Decimal('0.4329')),
#  ('W106', 'L15260', 'R6', 'Austin', 'TX', 78705, 'apartment', '2', 'Y', 'N', 1900, 80, 583, 212, Decimal('0.6959')),
#  ('W107', 'L15260', 'R10', 'Austin', 'TX', 78705, 'house', '1', 'Y', 'N', 1800, 239, 1431, 969, Decimal('0.1096')),
#  ('W108', 'L15260', 'R14', 'Austin', 'TX', 78705, 'house', '2', 'Y', 'N', 3200, 236, 1533, 885, Decimal('0.2247')),
#  ('W109', 'L15264', 'R2', 'Austin', 'TX', 78723, 'apartment', '1', 'Y', 'N', 1000, 138, 550, 287, Decimal('0.2192')),
#  ('W11', 'L9533', 'R10', 'Chapel Hill', 'NC', 27517, 'house', '1', 'Y', 'N', 1000, 116, 296, 206, Decimal('0.3918')),
#  ('W110', 'L15264', 'R6', 'Austin', 'TX', 78723, 'apartment', '2', 'Y', 'N', 1300, 175, 917, 462, Decimal('0.5370')),
#  ('W111', 'L15264', 'R10', 'Austin', 'TX', 78723, 'house', '1', 'Y', 'N', 1200, 130, 821, 389, Decimal('0.5123')),
#  ('W112', 'L15264', 'R14', 'Austin', 'TX', 78723, 'house', '2', 'Y', 'N', 1600, 241, 866, 678, Decimal('0.3616')),
#  ('W113', 'L15278', 'R2', 'Austin', 'TX', 78744, 'apartment', '1', 'Y', 'N', 800, 134, 288, 163, Decimal('0.8438')),
#  ('W114', 'L15278', 'R6', 'Austin', 'TX', 78744, 'apartment', '2', 'Y', 'N', 1200, 234, 794, 374, Decimal('0.9151')),
#  ('W115', 'L15278', 'R10', 'Austin', 'TX', 78744, 'house', '1', 'Y', 'N', 900, 252, 547, 444, Decimal('0.4301')),
#  ('W116', 'L15278', 'R14', 'Austin', 'TX', 78744, 'house', '2', 'Y', 'N', 1100, 246, 616, 426, Decimal('0.4822')),
#  ('W117', 'L15280', 'R2', 'Austin', 'TX', 78746, 'apartment', '1', 'Y', 'N', 1000, 171, 457, 332, Decimal('0.4904')),
#  ('W118', 'L15280', 'R6', 'Austin', 'TX', 78746, 'apartment', '2', 'Y', 'N', 1400, 262, 567, 430, Decimal('0.5233')),
#  ('W119', 'L15280', 'R10', 'Austin', 'TX', 78746, 'house', '1', 'Y', 'N', 1500, 229, 859, 662, Decimal('0.4493')),
#  ('W12', 'L9533', 'R14', 'Chapel Hill', 'NC', 27517, 'house', '2', 'Y', 'N', 1300, 136, 336, 186, Decimal('0.6603')),
#  ('W120', 'L15280', 'R14', 'Austin', 'TX', 78746, 'house', '2', 'Y', 'N', 1600, 449, 899, 696, Decimal('0.4877')),
#  ('W121', 'L463', 'R2', 'Bentonville', 'AR', 72712, 'apartment', '1', 'Y', 'N', 600, 132, 226, 182, Decimal('0.4384')),
#  ('W122', 'L463', 'R6', 'Bentonville', 'AR', 72712, 'apartment', '2', 'Y', 'N', 800, 157, 340, 241, Decimal('0.5315')),
#  ('W123', 'L463', 'R10', 'Bentonville', 'AR', 72712, 'house', '1', 'Y', 'N', 700, 215, 377, 363, Decimal('0.1397')),
#  ('W124', 'L463', 'R14', 'Bentonville', 'AR', 72712, 'house', '2', 'Y', 'N', 1000, 202, 374, 301, Decimal('0.4685')),
#  ('W125', 'L464', 'R2', 'Bentonville', 'AR', 72719, 'apartment', '1', 'Y', 'N', 700, 94, 356, 212, Decimal('0.5014')),
#  ('W126', 'L464', 'R6', 'Bentonville', 'AR', 72719, 'apartment', '2', 'Y', 'N', 900, 69, 485, 340, Decimal('0.3068')),
#  ('W127', 'L464', 'R10', 'Bentonville', 'AR', 72719, 'house', '1', 'Y', 'N', 1000, 84, 376, 266, Decimal('0.5205')),
#  ('W128', 'L464', 'R14', 'Bentonville', 'AR', 72719, 'house', '2', 'Y', 'N', 1200, 109, 490, 442, Decimal('0.1288')),
#  ('W129', 'L2314', 'R2', 'Denver', 'CO', 80204, 'apartment', '1', 'Y', 'N', 1200, 145, 434, 354, Decimal('0.2411')),
#  ('W13', 'L9534', 'R6', 'Chapel Hill', 'NC', 27707, 'apartment', '2', 'Y', 'N', 920, 111, 147, 123, Decimal('0.4521')),
#  ('W130', 'L2314', 'R6', 'Denver', 'CO', 80204, 'apartment', '2', 'Y', 'N', 1300, 228, 457, 377, Decimal('0.4795')),
#  ('W131', 'L2314', 'R10', 'Denver', 'CO', 80204, 'house', '1', 'Y', 'N', 1100, 90, 375, 318, Decimal('0.2712')),
#  ('W132', 'L2314', 'R14', 'Denver', 'CO', 80204, 'house', '2', 'Y', 'N', 1200, 128, 238, 198, Decimal('0.4301')),
#  ('W133', 'L2318', 'R2', 'Denver', 'CO', 80209, 'apartment', '1', 'Y', 'N', 1300, 126, 188, 149, Decimal('0.5671')),
#  ('W134', 'L2318', 'R6', 'Denver', 'CO', 80209, 'apartment', '2', 'Y', 'N', 1700, 152, 247, 210, Decimal('0.3205')),
#  ('W135', 'L2318', 'R10', 'Denver', 'CO', 80209, 'house', '1', 'Y', 'N', 1200, 141, 263, 187, Decimal('0.4493')),
#  ('W136', 'L2318', 'R14', 'Denver', 'CO', 80209, 'house', '2', 'Y', 'N', 1900, 157, 314, 225, Decimal('0.5096')),
#  ('W137', 'L2323', 'R2', 'Denver', 'CO', 80218, 'apartment', '1', 'Y', 'N', 1000, 93, 159, 123, Decimal('0.7205')),
#  ('W138', 'L2323', 'R6', 'Denver', 'CO', 80218, 'apartment', '2', 'Y', 'N', 1500, 145, 462, 263, Decimal('0.4959')),
#  ('W139', 'L2323', 'R10', 'Denver', 'CO', 80218, 'house', '1', 'Y', 'N', 1300, 181, 316, 238, Decimal('0.4493')),
#  ('W14', 'L9534', 'R10', 'Chapel Hill', 'NC', 27707, 'house', '1', 'Y', 'N', 850, 96, 245, 146, Decimal('0.5315')),
#  ('W140', 'L2323', 'R14', 'Denver', 'CO', 80218, 'house', '2', 'Y', 'N', 1800, 145, 412, 349, Decimal('0.1507')),
#  ('W141', 'L2325', 'R2', 'Denver', 'CO', 80220, 'apartment', '1', 'Y', 'N', 1100, 99, 215, 147, Decimal('0.6000')),
#  ('W142', 'L2325', 'R6', 'Denver', 'CO', 80220, 'apartment', '2', 'Y', 'N', 1400, 120, 188, 151, Decimal('0.5260')),
#  ('W143', 'L2325', 'R10', 'Denver', 'CO', 80220, 'house', '1', 'Y', 'N', 1300, 263, 489, 429, Decimal('0.2110')),
#  ('W144', 'L2325', 'R14', 'Denver', 'CO', 80220, 'house', '2', 'Y', 'N', 1900, 335, 502, 441, Decimal('0.3315')),
#  ('W145', 'L2338', 'R2', 'Denver', 'CO', 80249, 'apartment', '1', 'Y', 'N', 900, 98, 195, 144, Decimal('0.3288')),
#  ('W146', 'L2338', 'R6', 'Denver', 'CO', 80249, 'apartment', '2', 'Y', 'N', 1400, 77, 260, 136, Decimal('0.6192')),
#  ('W147', 'L2338', 'R10', 'Denver', 'CO', 80249, 'house', '1', 'Y', 'N', 1400, 173, 322, 305, Decimal('0.2712')),
#  ('W148', 'L2338', 'R14', 'Denver', 'CO', 80249, 'house', '2', 'Y', 'N', 1700, 176, 469, 425, Decimal('0.3288')),
#  ('W149', 'L3244', 'R2', 'Miami', 'FL', 33122, 'apartment', '1', 'Y', 'N', 800, 86, 224, 176, Decimal('0.4137')),
#  ('W15', 'L9534', 'R14', 'Chapel Hill', 'NC', 27707, 'house', '2', 'Y', 'N', 900, 111, 276, 169, Decimal('0.4795')),
#  ('W150', 'L3244', 'R6', 'Miami', 'FL', 33122, 'apartment', '2', 'Y', 'N', 1300, 127, 276, 207, Decimal('0.6301')),
#  ('W151', 'L3244', 'R10', 'Miami', 'FL', 33122, 'house', '1', 'Y', 'N', 1400, 222, 381, 244, Decimal('0.9041')),
#  ('W152', 'L3244', 'R14', 'Miami', 'FL', 33122, 'house', '2', 'Y', 'N', 1900, 386, 773, 536, Decimal('0.5425')),
#  ('W153', 'L3256', 'R2', 'Miami', 'FL', 33137, 'apartment', '1', 'Y', 'N', 1700, 136, 476, 476, Decimal('0.0795')),
#  ('W154', 'L3256', 'R6', 'Miami', 'FL', 33137, 'apartment', '2', 'Y', 'N', 2400, 173, 690, 360, Decimal('0.5507')),
#  ('W155', 'L3256', 'R10', 'Miami', 'FL', 33137, 'house', '1', 'Y', 'N', 2100, 448, 2128, 1477, Decimal('0.6932')),
#  ('W156', 'L3256', 'R14', 'Miami', 'FL', 33137, 'house', '2', 'Y', 'N', 3200, 450, 2699, 1265, Decimal('0.7151')),
#  ('W157', 'L3261', 'R2', 'Miami', 'FL', 33146, 'apartment', '1', 'Y', 'N', 1300, 291, 387, 328, Decimal('0.5205')),
#  ('W158', 'L3261', 'R6', 'Miami', 'FL', 33146, 'apartment', '2', 'Y', 'N', 1700, 203, 318, 246, Decimal('0.1589')),
#  ('W159', 'L3261', 'R10', 'Miami', 'FL', 33146, 'house', '1', 'Y', 'N', 1400, 287, 395, 325, Decimal('0.5452')),
#  ('W16', 'L9534', 'R2', 'Chapel Hill', 'NC', 27707, 'apartment', '1', 'Y', 'N', 750, 51, 179, 94, Decimal('0.4795')),
#  ('W160', 'L3261', 'R14', 'Miami', 'FL', 33146, 'house', '2', 'Y', 'N', 1900, 376, 502, 428, Decimal('0.5863')),
#  ('W161', 'L3262', 'R2', 'Miami', 'FL', 33149, 'apartment', '1', 'Y', 'N', 1600, 126, 352, 188, Decimal('0.6795')),
#  ('W162', 'L3262', 'R6', 'Miami', 'FL', 33149, 'apartment', '2', 'Y', 'N', 2200, 119, 505, 274, Decimal('0.5781')),
#  ('W163', 'L3262', 'R10', 'Miami', 'FL', 33149, 'house', '1', 'Y', 'N', 1500, 486, 1215, 860, Decimal('0.4110')),
#  ('W164', 'L3262', 'R14', 'Miami', 'FL', 33149, 'house', '2', 'Y', 'N', 2400, 516, 1650, 729, Decimal('0.6822')),
#  ('W165', 'L3264', 'R2', 'Miami', 'FL', 33178, 'apartment', '1', 'Y', 'N', 1600, 160, 321, 174, Decimal('0.8247')),
#  ('W166', 'L3264', 'R6', 'Miami', 'FL', 33178, 'apartment', '2', 'Y', 'N', 1900, 168, 364, 308, Decimal('0.2164')),
#  ('W167', 'L3264', 'R10', 'Miami', 'FL', 33178, 'house', '1', 'Y', 'N', 1400, 226, 368, 308, Decimal('0.6000')),
#  ('W168', 'L3264', 'R14', 'Miami', 'FL', 33178, 'house', '2', 'Y', 'N', 2000, 285, 428, 342, Decimal('0.3918')),
#  ('W169', 'L10126', 'R2', 'Omaha', 'NE', 68046, 'apartment', '1', 'Y', 'N', 1000, 91, 342, 229, Decimal('0.5890')),
#  ('W17', 'L4761', 'R6', 'Chicago', 'IL', 60607, 'apartment', '2', 'Y', 'N', 2500, 173, 581, 392, Decimal('0.2932')),
#  ('W170', 'L10126', 'R6', 'Omaha', 'NE', 68046, 'apartment', '2', 'Y', 'N', 1400, 168, 392, 322, Decimal('0.2712')),
#  ('W171', 'L10126', 'R10', 'Omaha', 'NE', 68046, 'house', '1', 'Y', 'N', 1300, 155, 494, 257, Decimal('0.5507')),
#  ('W172', 'L10126', 'R14', 'Omaha', 'NE', 68046, 'house', '2', 'Y', 'N', 1800, 151, 391, 286, Decimal('0.4521')),
#  ('W173', 'L10130', 'R2', 'Omaha', 'NE', 68106, 'apartment', '1', 'Y', 'N', 700, 99, 265, 180, Decimal('0.5178')),
#  ('W174', 'L10130', 'R6', 'Omaha', 'NE', 68106, 'apartment', '2', 'Y', 'N', 900, 154, 286, 230, Decimal('0.5205')),
#  ('W175', 'L10130', 'R10', 'Omaha', 'NE', 68106, 'house', '1', 'Y', 'N', 1000, 190, 462, 221, Decimal('0.6301')),
#  ('W176', 'L10130', 'R14', 'Omaha', 'NE', 68106, 'house', '2', 'Y', 'N', 1200, 205, 411, 316, Decimal('0.3699')),
#  ('W177', 'L10133', 'R2', 'Omaha', 'NE', 68110, 'apartment', '1', 'Y', 'N', 700, 192, 313, 245, Decimal('0.5699')),
#  ('W178', 'L10133', 'R6', 'Omaha', 'NE', 68110, 'apartment', '2', 'Y', 'N', 1000, 192, 357, 266, Decimal('0.4192')),
#  ('W179', 'L10133', 'R10', 'Omaha', 'NE', 68110, 'house', '1', 'Y', 'N', 800, 186, 465, 325, Decimal('0.4548')),
#  ('W18', 'L4761', 'R10', 'Chicago', 'IL', 60607, 'house', '1', 'Y', 'N', 2500, 189, 588, 393, Decimal('0.6219')),
#  ('W180', 'L10133', 'R14', 'Omaha', 'NE', 68110, 'house', '2', 'Y', 'N', 900, 209, 358, 256, Decimal('0.7096')),
#  ('W181', 'L10136', 'R2', 'Omaha', 'NE', 68114, 'apartment', '1', 'Y', 'N', 700, 42, 252, 184, Decimal('0.3096')),
#  ('W182', 'L10136', 'R6', 'Omaha', 'NE', 68114, 'apartment', '2', 'Y', 'N', 1000, 94, 531, 427, Decimal('0.2411')),
#  ('W183', 'L10136', 'R10', 'Omaha', 'NE', 68114, 'house', '1', 'Y', 'N', 900, 86, 488, 418, Decimal('0.0466')),
#  ('W184', 'L10136', 'R14', 'Omaha', 'NE', 68114, 'house', '2', 'Y', 'N', 1200, 83, 556, 219, Decimal('0.6356')),
#  ('W185', 'L1882', 'R2', 'San Diego', 'CA', 91910, 'apartment', '1', 'Y', 'N', 1100, 84, 301, 220, Decimal('0.4301')),
#  ('W186', 'L1882', 'R6', 'San Diego', 'CA', 91910, 'apartment', '2', 'Y', 'N', 1400, 134, 568, 481, Decimal('0.3808')),
#  ('W187', 'L1882', 'R10', 'San Diego', 'CA', 91910, 'house', '1', 'Y', 'N', 1300, 109, 615, 280, Decimal('0.4575')),
#  ('W188', 'L1882', 'R14', 'San Diego', 'CA', 91910, 'house', '2', 'Y', 'N', 1900, 227, 861, 568, Decimal('0.1890')),
#  ('W189', 'L1883', 'R2', 'San Diego', 'CA', 91950, 'apartment', '1', 'Y', 'N', 900, 176, 440, 318, Decimal('0.2904')),
#  ('W19', 'L4761', 'R14', 'Chicago', 'IL', 60607, 'house', '2', 'Y', 'N', 2800, 191, 826, 556, Decimal('0.2986')),
#  ('W190', 'L1883', 'R6', 'San Diego', 'CA', 91950, 'apartment', '2', 'Y', 'N', 1100, 225, 1033, 538, Decimal('0.5808')),
#  ('W191', 'L1883', 'R10', 'San Diego', 'CA', 91950, 'house', '1', 'Y', 'N', 1300, 157, 471, 318, Decimal('0.3918')),
#  ('W192', 'L1883', 'R14', 'San Diego', 'CA', 91950, 'house', '2', 'Y', 'N', 1600, 253, 886, 680, Decimal('0.3863')),
#  ('W193', 'L1887', 'R2', 'San Diego', 'CA', 92102, 'apartment', '1', 'Y', 'N', 1400, 76, 342, 202, Decimal('0.4877')),
#  ('W194', 'L1887', 'R6', 'San Diego', 'CA', 92102, 'apartment', '2', 'Y', 'N', 2000, 107, 781, 579, Decimal('0.4110')),
#  ('W195', 'L1887', 'R10', 'San Diego', 'CA', 92102, 'house', '1', 'Y', 'N', 1700, 162, 614, 524, Decimal('0.5041')),
#  ('W196', 'L1887', 'R14', 'San Diego', 'CA', 92102, 'house', '2', 'Y', 'N', 2500, 158, 906, 560, Decimal('0.2767')),
#  ('W197', 'L1902', 'R2', 'San Diego', 'CA', 92118, 'apartment', '1', 'Y', 'N', 1800, 199, 432, 362, Decimal('0.3288')),
#  ('W198', 'L1902', 'R6', 'San Diego', 'CA', 92118, 'apartment', '2', 'Y', 'N', 2600, 366, 594, 417, Decimal('0.5315')),
#  ('W199', 'L1902', 'R10', 'San Diego', 'CA', 92118, 'house', '1', 'Y', 'N', 2500, 333, 665, 474, Decimal('0.4274')),
#  ('W2', 'L9531', 'R10', 'Chapel Hill', 'NC', 27514, 'house', '1', 'Y', 'N', 1500, 81, 205, 146, Decimal('0.2411')),
#  ('W20', 'L4761', 'R2', 'Chicago', 'IL', 60607, 'apartment', '1', 'Y', 'N', 1700, 106, 465, 312, Decimal('0.4110')),
#  ('W200', 'L1902', 'R14', 'San Diego', 'CA', 92118, 'house', '2', 'Y', 'N', 3600, 336, 624, 491, Decimal('0.3973')),
#  ('W201', 'L1916', 'R2', 'San Diego', 'CA', 92154, 'apartment', '1', 'Y', 'N', 1200, 173, 395, 204, Decimal('0.7973')),
#  ('W202', 'L1916', 'R6', 'San Diego', 'CA', 92154, 'apartment', '2', 'Y', 'N', 1600, 228, 456, 245, Decimal('0.6877')),
#  ('W203', 'L1916', 'R10', 'San Diego', 'CA', 92154, 'house', '1', 'Y', 'N', 1000, 155, 252, 197, Decimal('0.5890')),
#  ('W204', 'L1916', 'R14', 'San Diego', 'CA', 92154, 'house', '2', 'Y', 'N', 1500, 158, 236, 195, Decimal('0.6192')),
#  ('W205', 'L12252', 'R2', 'Columbus', 'OH', 43201, 'apartment', '1', 'Y', 'N', 750, 89, 155, 124, Decimal('0.4548')),
#  ('W206', 'L12252', 'R6', 'Columbus', 'OH', 43201, 'apartment', '2', 'Y', 'N', 1040, 115, 179, 156, Decimal('0.4877')),
#  ('W207', 'L12252', 'R10', 'Columbus', 'OH', 43201, 'house', '1', 'Y', 'N', 900, 152, 300, 256, Decimal('0.4795')),
#  ('W208', 'L12252', 'R14', 'Columbus', 'OH', 43201, 'house', '2', 'Y', 'N', 1400, 175, 368, 284, Decimal('0.4932')),
#  ('W209', 'L12260', 'R2', 'Columbus', 'OH', 43212, 'apartment', '1', 'Y', 'N', 825, 77, 161, 128, Decimal('0.3616')),
#  ('W21', 'L4765', 'R6', 'Chicago', 'IL', 60611, 'apartment', '2', 'Y', 'N', 2700, 157, 526, 337, Decimal('0.4219')),
#  ('W210', 'L12260', 'R6', 'Columbus', 'OH', 43212, 'apartment', '2', 'Y', 'N', 1300, 125, 170, 139, Decimal('0.7425')),
#  ('W211', 'L12260', 'R10', 'Columbus', 'OH', 43212, 'house', '1', 'Y', 'N', 1000, 140, 288, 240, Decimal('0.3699')),
#  ('W212', 'L12260', 'R14', 'Columbus', 'OH', 43212, 'house', '2', 'Y', 'N', 1480, 175, 310, 249, Decimal('0.4411')),
#  ('W213', 'L12264', 'R2', 'Columbus', 'OH', 43222, 'apartment', '1', 'Y', 'N', 650, 80, 156, 107, Decimal('0.4795')),
#  ('W214', 'L12264', 'R6', 'Columbus', 'OH', 43222, 'apartment', '2', 'Y', 'N', 920, 108, 205, 147, Decimal('0.4137')),
#  ('W215', 'L12264', 'R10', 'Columbus', 'OH', 43222, 'house', '1', 'Y', 'N', 880, 145, 333, 246, Decimal('0.4438')),
#  ('W216', 'L12264', 'R14', 'Columbus', 'OH', 43222, 'house', '2', 'Y', 'N', 1200, 160, 310, 169, Decimal('0.6192')),
#  ('W217', 'L16888', 'R2', 'Richmond', 'VA', 23113, 'apartment', '1', 'Y', 'N', 1000, 95, 280, 174, Decimal('0.5479')),
#  ('W218', 'L16888', 'R6', 'Richmond', 'VA', 23113, 'apartment', '2', 'Y', 'N', 1200, 125, 277, 203, Decimal('0.2712')),
#  ('W219', 'L16888', 'R10', 'Richmond', 'VA', 23113, 'house', '1', 'Y', 'N', 1400, 209, 384, 240, Decimal('0.7616')),
#  ('W22', 'L4765', 'R10', 'Chicago', 'IL', 60611, 'house', '1', 'Y', 'N', 2700, 202, 629, 389, Decimal('0.5123')),
#  ('W220', 'L16888', 'R14', 'Richmond', 'VA', 23113, 'house', '2', 'Y', 'N', 1600, 220, 418, 312, Decimal('0.6082')),
#  ('W221', 'L16887', 'R2', 'Richmond', 'VA', 23060, 'apartment', '1', 'Y', 'N', 1105, 82, 235, 111, Decimal('0.6110')),
#  ('W222', 'L16887', 'R6', 'Richmond', 'VA', 23060, 'apartment', '2', 'Y', 'N', 1665, 130, 200, 169, Decimal('0.3068')),
#  ('W223', 'L16887', 'R10', 'Richmond', 'VA', 23060, 'house', '1', 'Y', 'N', 1175, 106, 267, 201, Decimal('0.5233')),
#  ('W224', 'L16887', 'R14', 'Richmond', 'VA', 23060, 'house', '2', 'Y', 'N', 1725, 195, 305, 242, Decimal('0.4822')),
#  ('W225', 'L16898', 'R2', 'Richmond', 'VA', 23234, 'apartment', '1', 'Y', 'N', 709, 86, 192, 158, Decimal('0.2219')),
#  ('W226', 'L16898', 'R6', 'Richmond', 'VA', 23234, 'apartment', '2', 'Y', 'N', 869, 135, 305, 246, Decimal('0.3890')),
#  ('W227', 'L16898', 'R10', 'Richmond', 'VA', 23234, 'house', '1', 'Y', 'N', 925, 125, 288, 207, Decimal('0.4164')),
#  ('W228', 'L16898', 'R14', 'Richmond', 'VA', 23234, 'house', '2', 'Y', 'N', 1350, 119, 360, 224, Decimal('0.4849')),
#  ('W229', 'L16890', 'R2', 'Richmond', 'VA', 23220, 'apartment', '1', 'Y', 'N', 900, 89, 177, 139, Decimal('0.5507')),
#  ('W23', 'L4765', 'R14', 'Chicago', 'IL', 60611, 'house', '2', 'Y', 'N', 3200, 195, 844, 325, Decimal('0.8164')),
#  ('W230', 'L16890', 'R6', 'Richmond', 'VA', 23220, 'apartment', '2', 'Y', 'N', 1325, 161, 319, 283, Decimal('0.2932')),
#  ('W231', 'L16890', 'R10', 'Richmond', 'VA', 23220, 'house', '1', 'Y', 'N', 975, 145, 300, 192, Decimal('0.5014')),
#  ('W232', 'L16890', 'R14', 'Richmond', 'VA', 23220, 'house', '2', 'Y', 'N', 1550, 185, 376, 307, Decimal('0.3014')),
#  ('W233', 'L14416', 'R2', 'Charleston', 'SC', 29438, 'apartment', '1', 'Y', 'N', 1165, 135, 220, 180, Decimal('0.3425')),
#  ('W234', 'L14416', 'R6', 'Charleston', 'SC', 29438, 'apartment', '2', 'Y', 'N', 1625, 220, 312, 260, Decimal('0.6000')),
#  ('W235', 'L14416', 'R10', 'Charleston', 'SC', 29438, 'house', '1', 'Y', 'N', 1400, 135, 287, 232, Decimal('0.4986')),
#  ('W236', 'L14416', 'R14', 'Charleston', 'SC', 29438, 'house', '2', 'Y', 'N', 1995, 224, 331, 292, Decimal('0.6384')),
#  ('W237', 'L14418', 'R2', 'Charleston', 'SC', 29470, 'apartment', '1', 'Y', 'N', 760, 100, 195, 169, Decimal('0.2904')),
#  ('W238', 'L14418', 'R6', 'Charleston', 'SC', 29470, 'apartment', '2', 'Y', 'N', 965, 135, 284, 189, Decimal('0.5397')),
#  ('W239', 'L14418', 'R10', 'Charleston', 'SC', 29470, 'house', '1', 'Y', 'N', 1185, 157, 320, 289, Decimal('0.2795')),
#  ('W24', 'L4765', 'R2', 'Chicago', 'IL', 60611, 'apartment', '1', 'Y', 'N', 1700, 98, 430, 239, Decimal('0.6767')),
#  ('W240', 'L14418', 'R14', 'Charleston', 'SC', 29470, 'house', '2', 'Y', 'N', 1340, 135, 347, 278, Decimal('0.3890')),
#  ('W241', 'L14419', 'R2', 'Charleston', 'SC', 29487, 'apartment', '1', 'Y', 'N', 1150, 80, 267, 183, Decimal('0.5753')),
#  ('W242', 'L14419', 'R6', 'Charleston', 'SC', 29487, 'apartment', '2', 'Y', 'N', 2000, 160, 323, 237, Decimal('0.3123')),
#  ('W243', 'L14419', 'R10', 'Charleston', 'SC', 29487, 'house', '1', 'Y', 'N', 1600, 225, 406, 297, Decimal('0.4521')),
#  ('W244', 'L14419', 'R14', 'Charleston', 'SC', 29487, 'house', '2', 'Y', 'N', 2150, 170, 447, 360, Decimal('0.5315')),
#  ('W25', 'L4770', 'R2', 'Chicago', 'IL', 60616, 'apartment', '1', 'Y', 'N', 1600, 94, 411, 209, Decimal('0.5397')),
#  ('W26', 'L4770', 'R6', 'Chicago', 'IL', 60616, 'apartment', '2', 'Y', 'N', 2100, 130, 438, 265, Decimal('0.4027')),
#  ('W27', 'L4770', 'R10', 'Chicago', 'IL', 60616, 'house', '1', 'Y', 'N', 1200, 162, 504, 435, Decimal('0.4000')),
#  ('W28', 'L4770', 'R14', 'Chicago', 'IL', 60616, 'house', '2', 'Y', 'N', 2100, 175, 755, 487, Decimal('0.4301')),
#  ('W29', 'L4794', 'R6', 'Chicago', 'IL', 60642, 'apartment', '2', 'Y', 'N', 2500, 129, 431, 231, Decimal('0.4027')),
#  ('W3', 'L9531', 'R14', 'Chapel Hill', 'NC', 27514, 'house', '2', 'Y', 'N', 2000, 97, 240, 199, Decimal('0.3123')),
#  ('W30', 'L4794', 'R10', 'Chicago', 'IL', 60642, 'house', '1', 'Y', 'N', 2500, 186, 578, 490, Decimal('0.2301')),
#  ('W31', 'L4794', 'R14', 'Chicago', 'IL', 60642, 'house', '2', 'Y', 'N', 2750, 188, 810, 538, Decimal('0.6000')),
#  ('W32', 'L4794', 'R2', 'Chicago', 'IL', 60642, 'apartment', '1', 'Y', 'N', 1800, 89, 390, 288, Decimal('0.2329')),
#  ('W33', 'L4804', 'R6', 'Chicago', 'IL', 60654, 'apartment', '2', 'Y', 'N', 3000, 193, 648, 415, Decimal('0.4082')),
#  ('W34', 'L4804', 'R10', 'Chicago', 'IL', 60654, 'house', '1', 'Y', 'N', 2000, 193, 600, 387, Decimal('0.3260')),
#  ('W35', 'L4804', 'R14', 'Chicago', 'IL', 60654, 'house', '2', 'Y', 'N', 2950, 192, 829, 575, Decimal('0.3890')),
#  ('W36', 'L4804', 'R2', 'Chicago', 'IL', 60654, 'apartment', '1', 'Y', 'N', 1700, 98, 432, 228, Decimal('0.5205')),
#  ('W37', 'L11419', 'R2', 'New York', 'NY', 10002, 'apartment', '1', 'Y', 'N', 3000, 87, 512, 337, Decimal('0.4630')),
#  ('W38', 'L11419', 'R6', 'New York', 'NY', 10002, 'apartment', '2', 'Y', 'N', 3200, 154, 480, 154, Decimal('0.6795')),
#  ('W39', 'L11421', 'R6', 'New York', 'NY', 10004, 'apartment', '2', 'Y', 'N', 4500, 273, 853, 432, Decimal('0.6822')),
#  ('W4', 'L9531', 'R2', 'Chapel Hill', 'NC', 27514, 'apartment', '1', 'Y', 'N', 800, 53, 188, 104, Decimal('0.5699')),
#  ('W40', 'L11421', 'R10', 'New York', 'NY', 10004, 'house', '1', 'Y', 'N', 4500, 103, 807, 200, Decimal('0.8685')),
#  ('W41', 'L11421', 'R14', 'New York', 'NY', 10004, 'house', '2', 'Y', 'N', 5500, 200, 770, 428, Decimal('0.5233')),
#  ('W42', 'L11421', 'R2', 'New York', 'NY', 10004, 'apartment', '1', 'Y', 'N', 3500, 151, 890, 576, Decimal('0.4603')),
#  ('W43', 'L11427', 'R6', 'New York', 'NY', 10014, 'apartment', '2', 'Y', 'N', 4000, 218, 681, 560, Decimal('0.3534')),
#  ('W44', 'L11427', 'R2', 'New York', 'NY', 10014, 'apartment', '1', 'Y', 'N', 3000, 109, 640, 288, Decimal('0.4986')),
#  ('W45', 'L11431', 'R6', 'New York', 'NY', 10019, 'apartment', '2', 'Y', 'N', 5600, 196, 612, 373, Decimal('0.5151')),
#  ('W46', 'L11431', 'R10', 'New York', 'NY', 10019, 'house', '1', 'Y', 'N', 3200, 165, 1296, 420, Decimal('0.8712')),
#  ('W47', 'L11431', 'R14', 'New York', 'NY', 10019, 'house', '2', 'Y', 'N', 3500, 268, 1032, 593, Decimal('0.5068')),
#  ('W48', 'L11431', 'R2', 'New York', 'NY', 10019, 'apartment', '1', 'Y', 'N', 3400, 106, 624, 436, Decimal('0.2822')),
#  ('W49', 'L11434', 'R6', 'New York', 'NY', 10023, 'apartment', '2', 'Y', 'N', 4200, 210, 654, 426, Decimal('0.5425')),
#  ('W5', 'L9532', 'R6', 'Chapel Hill', 'NC', 27516, 'apartment', '2', 'Y', 'N', 1100, 111, 148, 142, Decimal('0.0822')),
#  ('W50', 'L11434', 'R10', 'New York', 'NY', 10023, 'house', '1', 'Y', 'N', 3000, 133, 1040, 621, Decimal('0.3479')),
#  ('W51', 'L11434', 'R14', 'New York', 'NY', 10023, 'house', '2', 'Y', 'N', 3900, 231, 888, 535, Decimal('0.4767')),
#  ('W52', 'L11434', 'R2', 'New York', 'NY', 10023, 'apartment', '1', 'Y', 'N', 3600, 137, 808, 196, Decimal('0.7781')),
#  ('W53', 'L11480', 'R6', 'New York', 'NY', 11101, 'apartment', '2', 'Y', 'N', 3500, 155, 483, 294, Decimal('0.3973')),
#  ('W54', 'L11480', 'R10', 'New York', 'NY', 11101, 'house', '1', 'Y', 'N', 2500, 111, 868, 471, Decimal('0.6000')),
#  ('W55', 'L11480', 'R14', 'New York', 'NY', 11101, 'house', '2', 'Y', 'N', 3000, 195, 752, 620, Decimal('0.2932')),
#  ('W56', 'L11480', 'R2', 'New York', 'NY', 11101, 'apartment', '1', 'Y', 'N', 3000, 80, 469, 235, Decimal('0.6411')),
#  ('W57', 'L11495', 'R6', 'New York', 'NY', 11211, 'apartment', '2', 'Y', 'N', 3900, 116, 361, 284, Decimal('0.5041')),
#  ('W58', 'L11495', 'R10', 'New York', 'NY', 11211, 'house', '1', 'Y', 'N', 2800, 102, 799, 355, Decimal('0.4027')),
#  ('W59', 'L11495', 'R14', 'New York', 'NY', 11211, 'house', '2', 'Y', 'N', 3500, 188, 724, 436, Decimal('0.5068')),
#  ('W6', 'L9532', 'R10', 'Chapel Hill', 'NC', 27516, 'house', '1', 'Y', 'N', 900, 116, 296, 141, Decimal('0.5479')),
#  ('W60', 'L11495', 'R2', 'New York', 'NY', 11211, 'apartment', '1', 'Y', 'N', 2600, 69, 406, 250, Decimal('0.3699')),
#  ('W61', 'L1734', 'R6', 'Palo Alto', 'CA', 94025, 'apartment', '2', 'Y', 'N', 2695, 265, 534, 443, Decimal('0.2356')),
#  ('W62', 'L1734', 'R10', 'Palo Alto', 'CA', 94025, 'house', '1', 'Y', 'N', 3000, 158, 706, 343, Decimal('0.5808')),
#  ('W63', 'L1734', 'R14', 'Palo Alto', 'CA', 94025, 'house', '2', 'Y', 'N', 4000, 306, 781, 739, Decimal('0.0192')),
#  ('W64', 'L1734', 'R2', 'Palo Alto', 'CA', 94025, 'apartment', '1', 'Y', 'N', 2295, 100, 469, 270, Decimal('0.4685')),
#  ('W65', 'L1735', 'R6', 'Palo Alto', 'CA', 94301, 'apartment', '2', 'Y', 'N', 3000, 270, 543, 424, Decimal('0.3425')),
#  ('W66', 'L1735', 'R10', 'Palo Alto', 'CA', 94301, 'house', '1', 'Y', 'N', 3300, 283, 1261, 980, Decimal('0.2712')),
#  ('W67', 'L1735', 'R14', 'Palo Alto', 'CA', 94301, 'house', '2', 'Y', 'N', 4500, 530, 1354, 994, Decimal('0.4301')),
#  ('W68', 'L1735', 'R2', 'Palo Alto', 'CA', 94301, 'apartment', '1', 'Y', 'N', 2700, 103, 483, 284, Decimal('0.6055')),
#  ('W69', 'L1736', 'R2', 'Palo Alto', 'CA', 94303, 'apartment', '1', 'Y', 'N', 2700, 110, 515, 236, Decimal('0.5671')),
#  ('W7', 'L9532', 'R14', 'Chapel Hill', 'NC', 27516, 'house', '2', 'Y', 'N', 1100, 136, 335, 188, Decimal('0.6192')),
#  ('W70', 'L1736', 'R6', 'Palo Alto', 'CA', 94303, 'apartment', '2', 'Y', 'N', 3000, 270, 544, 329, Decimal('0.7041')),
#  ('W71', 'L1736', 'R10', 'Palo Alto', 'CA', 94303, 'house', '1', 'Y', 'N', 4500, 231, 1027, 549, Decimal('0.4438')),
#  ('W72', 'L1736', 'R14', 'Palo Alto', 'CA', 94303, 'house', '2', 'Y', 'N', 4900, 379, 969, 652, Decimal('0.4466')),
#  ('W73', 'L1737', 'R6', 'Palo Alto', 'CA', 94305, 'apartment', '2', 'Y', 'N', 3300, 264, 532, 378, Decimal('0.4219')),
#  ('W74', 'L1737', 'R10', 'Palo Alto', 'CA', 94305, 'house', '1', 'Y', 'N', 4500, 151, 673, 255, Decimal('0.5918')),
#  ('W75', 'L1737', 'R14', 'Palo Alto', 'CA', 94305, 'house', '2', 'Y', 'N', 4200, 278, 711, 441, Decimal('0.5726')),
#  ('W76', 'L1737', 'R2', 'Palo Alto', 'CA', 94305, 'apartment', '1', 'Y', 'N', 2500, 98, 460, 356, Decimal('0.4247')),
#  ('W77', 'L1738', 'R2', 'Palo Alto', 'CA', 94306, 'apartment', '1', 'Y', 'N', 2500, 108, 507, 437, Decimal('0.0795')),
#  ('W78', 'L1738', 'R6', 'Palo Alto', 'CA', 94306, 'apartment', '2', 'Y', 'N', 3300, 270, 543, 461, Decimal('0.3178')),
#  ('W79', 'L1738', 'R10', 'Palo Alto', 'CA', 94306, 'house', '1', 'Y', 'N', 4500, 186, 829, 669, Decimal('0.3123')),
#  ('W8', 'L9532', 'R2', 'Chapel Hill', 'NC', 27516, 'apartment', '1', 'Y', 'N', 500, 50, 174, 121, Decimal('0.3973')),
#  ('W80', 'L1738', 'R14', 'Palo Alto', 'CA', 94306, 'house', '2', 'Y', 'N', 4200, 319, 815, 437, Decimal('0.6110')),
#  ('W81', 'L1940', 'R6', 'San Francisco', 'CA', 94103, 'apartment', '2', 'Y', 'N', 3600, 332, 805, 663, Decimal('0.2329')),
#  ('W82', 'L1940', 'R10', 'San Francisco', 'CA', 94103, 'house', '1', 'Y', 'N', 4000, 179, 629, 337, Decimal('0.5068')),
#  ('W83', 'L1940', 'R14', 'San Francisco', 'CA', 94103, 'house', '2', 'Y', 'N', 5500, 227, 813, 447, Decimal('0.6164')),
#  ('W84', 'L1940', 'R2', 'San Francisco', 'CA', 94103, 'apartment', '1', 'Y', 'N', 3000, 115, 650, 610, Decimal('0.1014')),
#  ('W85', 'L1941', 'R6', 'San Francisco', 'CA', 94110, 'apartment', '2', 'Y', 'N', 4000, 220, 534, 302, Decimal('0.3151')),
#  ('W86', 'L1941', 'R10', 'San Francisco', 'CA', 94110, 'house', '1', 'Y', 'N', 4000, 128, 450, 213, Decimal('0.6521')),
#  ('W87', 'L1941', 'R14', 'San Francisco', 'CA', 94110, 'house', '2', 'Y', 'N', 5000, 152, 546, 364, Decimal('0.5123')),
#  ('W88', 'L1941', 'R2', 'San Francisco', 'CA', 94110, 'apartment', '1', 'Y', 'N', 3200, 94, 528, 251, Decimal('0.6274')),
#  ('W89', 'L1942', 'R6', 'San Francisco', 'CA', 94112, 'apartment', '2', 'Y', 'N', 3500, 194, 471, 343, Decimal('0.3973')),
#  ('W9', 'L9533', 'R2', 'Chapel Hill', 'NC', 27517, 'apartment', '1', 'Y', 'N', 965, 50, 174, 125, Decimal('0.3753')),
#  ('W90', 'L1942', 'R10', 'San Francisco', 'CA', 94112, 'house', '1', 'Y', 'N', 3200, 138, 485, 251, Decimal('0.3342')),
#  ('W91', 'L1942', 'R14', 'San Francisco', 'CA', 94112, 'house', '2', 'Y', 'N', 3500, 152, 547, 404, Decimal('0.3616')),
#  ('W92', 'L1942', 'R2', 'San Francisco', 'CA', 94112, 'apartment', '1', 'Y', 'N', 3000, 77, 432, 161, Decimal('0.2658')),
#  ('W93', 'L1943', 'R2', 'San Francisco', 'CA', 94118, 'apartment', '1', 'Y', 'N', 2600, 100, 565, 408, Decimal('0.3863')),
#  ('W94', 'L1943', 'R6', 'San Francisco', 'CA', 94118, 'apartment', '2', 'Y', 'N', 4000, 204, 494, 284, Decimal('0.3151')),
#  ('W95', 'L1943', 'R10', 'San Francisco', 'CA', 94118, 'house', '1', 'Y', 'N', 4000, 257, 903, 443, Decimal('0.5562')),
#  ('W96', 'L1943', 'R14', 'San Francisco', 'CA', 94118, 'house', '2', 'Y', 'N', 5100, 256, 916, 718, Decimal('0.4493')),
#  ('W97', 'L1944', 'R6', 'San Francisco', 'CA', 94129, 'apartment', '2', 'Y', 'N', 5600, 265, 644, 478, Decimal('0.3178')),
#  ('W98', 'L1944', 'R10', 'San Francisco', 'CA', 94129, 'house', '1', 'Y', 'N', 5000, 236, 829, 533, Decimal('0.5123')),
#  ('W99', 'L1944', 'R14', 'San Francisco', 'CA', 94129, 'house', '2', 'Y', 'N', 6000, 244, 872, 566, Decimal('0.3699'))]

# %% [markdown]
# # Finally, export to csv file

# %%
Watershed_Properties_Data=%sql \
SELECT w.ws_property_id, w.location, w.property_type, l.city, l.state, l.zipcode, p.apt_house, p.num_bedrooms, p.kitchen, \
p.shared, w.current_monthly_rent, sample_price.percentile_10th_price, sample_price.percentile_90th_price, \
sample_price.sample_nightly_rent_price, sample_dates.Occupancy \
FROM watershed_property_info w, location l, property_type p, \
    (SELECT w.ws_property_id, w.location, w.property_type, \
     sp.percentile_10th_price, sp.percentile_90th_price, \
     sp.sample_nightly_rent_price \
     FROM watershed_property_info w JOIN st_rental_prices sp \
       ON w.location=sp.location AND w.property_type=sp.property_type \
     GROUP BY w.ws_property_id) AS sample_price, \
    (SELECT w.ws_property_id, w.location, w.property_type, Sample.Occupancy \
     FROM watershed_property_info w LEFT JOIN (SELECT si.location, si.property_type, sd.st_property, COUNT(sd.rental_date)/365 \
                                               AS Occupancy \
                                               FROM st_property_info si JOIN st_rental_dates sd \
                                                 ON si.st_property_id=sd.st_property \
                                               WHERE EXTRACT(year FROM rental_date)=2015 \
                                               GROUP BY st_property) AS Sample \
       ON w.location=Sample.location AND w.property_type=Sample.property_type \
     GROUP BY w.ws_property_id) AS sample_dates \
WHERE w.property_type=p.property_type_id AND w.location=l.location_id AND w.ws_property_id=sample_price.ws_property_id AND \
w.ws_property_id=sample_dates.ws_property_id \
GROUP BY w.ws_property_id;

Watershed_Properties_Data.csv('Watershed Properties Data.csv')
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# CSV results at /home/jovyan/work/Watershed Properties Data.csv
